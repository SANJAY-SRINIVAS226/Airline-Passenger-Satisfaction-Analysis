# %%
# !pip install  missingno
# Out:
# Requirement already satisfied: missingno in c:\users\admin\downloads\anacomoda\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\admin\downloads\anacomoda\lib\site-packages (from missingno) (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\admin\downloads\anacomoda\lib\site-packages (from missingno) (3.10.0)
# Requirement already satisfied: scipy in c:\users\admin\downloads\anacomoda\lib\site-packages (from missingno) (1.15.3)
# Requirement already satisfied: seaborn in c:\users\admin\downloads\anacomoda\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\downloads\anacomoda\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\downloads\anacomoda\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\downloads\anacomoda\lib\site-packages (from matplotlib->missingno) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\downloads\anacomoda\lib\site-packages (from matplotlib->missingno) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\downloads\anacomoda\lib\site-packages (from matplotlib->missingno) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\admin\downloads\anacomoda\lib\site-packages (from matplotlib->missingno) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\downloads\anacomoda\lib\site-packages (from matplotlib->missingno) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\downloads\anacomoda\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\downloads\anacomoda\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\admin\downloads\anacomoda\lib\site-packages (from seaborn->missingno) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\downloads\anacomoda\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\downloads\anacomoda\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)

# %%
import pandas as pd
import numpy as np
import math as math
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
# %matplotlib inline
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from IPython.display import Markdown, display
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
import json

import warnings
warnings.filterwarnings('ignore')

# %%
train_original = pd.read_csv('train.csv')
test_original = pd.read_csv('test.csv')

# %% [markdown]
# <strong>Check out the info(), head(), and describe() methods on impressions.<strong>

# %%
train_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
#  11  Gate location                      103904 non-null  int64
#  12  Food and drink                     103904 non-null  int64
#  13  Online boarding                    103904 non-null  int64
#  14  Seat comfort                       103904 non-null  int64
#  15  Inflight entertainment             103904 non-null  int64
#  16  On-board service                   103904 non-null  int64
#  17  Leg room service                   103904 non-null  int64
#  18  Baggage handling                   103904 non-null  int64
#  19  Checkin service                    103904 non-null  int64
#  20  Inflight service                   103904 non-null  int64
#  21  Cleanliness                        103904 non-null  int64
#  22  Departure Delay in Minutes         103904 non-null  int64
#  23  Arrival Delay in Minutes           103594 non-null  float64
#  24  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 19.8+ MB

# %%
test_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         25976 non-null  int64
#  1   id                                 25976 non-null  int64
#  2   Gender                             25976 non-null  object
#  3   Customer Type                      25976 non-null  object
#  4   Age                                25976 non-null  int64
#  5   Type of Travel                     25976 non-null  object
#  6   Class                              25976 non-null  object
#  7   Flight Distance                    25976 non-null  int64
#  8   Inflight wifi service              25976 non-null  int64
#  9   Departure/Arrival time convenient  25976 non-null  int64
#  10  Ease of Online booking             25976 non-null  int64
#  11  Gate location                      25976 non-null  int64
#  12  Food and drink                     25976 non-null  int64
#  13  Online boarding                    25976 non-null  int64
#  14  Seat comfort                       25976 non-null  int64
#  15  Inflight entertainment             25976 non-null  int64
#  16  On-board service                   25976 non-null  int64
#  17  Leg room service                   25976 non-null  int64
#  18  Baggage handling                   25976 non-null  int64
#  19  Checkin service                    25976 non-null  int64
#  20  Inflight service                   25976 non-null  int64
#  21  Cleanliness                        25976 non-null  int64
#  22  Departure Delay in Minutes         25976 non-null  int64
#  23  Arrival Delay in Minutes           25893 non-null  float64
#  24  satisfaction                       25976 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 5.0+ MB

# %%
train_original.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
test_original.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# 2                                  0  ...                       2
# 3                                  0  ...                       1
# 4                                  3  ...                       2
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 5                 5                 5                2
# 1                 4                 4                 4                3
# 2                 4                 1                 3                2
# 3                 1                 1                 1                3
# 4                 2                 2                 2                4
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          50
# 1                 4            5                           0
# 2                 2            2                           0
# 3                 1            4                           0
# 4                 2            4                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      44.0                satisfied
# 1                       0.0                satisfied
# 2                       0.0  neutral or dissatisfied
# 3                       6.0                satisfied
# 4                      20.0                satisfied
#
# [5 rows x 25 columns]

# %%
train_original.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# 25%                 2.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count           103904.000000  103904.000000   103904.000000    103904.000000
# mean                 2.756901       2.976883        3.202129         3.250375
# std                  1.398929       1.277621        1.329533         1.349509
# min                  0.000000       0.000000        0.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#         Seat comfort  Inflight entertainment  On-board service  \
# count  103904.000000           103904.000000     103904.000000
# mean        3.439396                3.358158          3.382363
# std         1.319088                1.332991          1.288354
# min         0.000000                0.000000          0.000000
# 25%         2.000000                2.000000          2.000000
# 50%         4.000000                4.000000          4.000000
# 75%         5.000000                4.000000          4.000000
# max         5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count     103904.000000     103904.000000    103904.000000     103904.000000
# mean           3.351055          3.631833         3.304290          3.640428
# std            1.315605          1.180903         1.265396          1.175663
# min            0.000000          1.000000         0.000000          0.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#          Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# count  103904.000000               103904.000000             103594.000000
# mean        3.286351                   14.815618                 15.178678
# std         1.312273                   38.230901                 38.698682
# min         0.000000                    0.000000                  0.000000
# 25%         2.000000                    0.000000                  0.000000
# 50%         3.000000                    0.000000                  0.000000
# 75%         4.000000                   12.000000                 13.000000
# max         5.000000                 1592.000000               1584.000000

# %%
test_original.describe()
# Out:
#          Unnamed: 0             id           Age  Flight Distance  \
# count  25976.000000   25976.000000  25976.000000     25976.000000
# mean   12987.500000   65005.657992     39.620958      1193.788459
# std     7498.769632   37611.526647     15.135685       998.683999
# min        0.000000      17.000000      7.000000        31.000000
# 25%     6493.750000   32170.500000     27.000000       414.000000
# 50%    12987.500000   65319.500000     40.000000       849.000000
# 75%    19481.250000   97584.250000     51.000000      1744.000000
# max    25975.000000  129877.000000     85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count           25976.000000                       25976.000000
# mean                2.724746                           3.046812
# std                 1.335384                           1.533371
# min                 0.000000                           0.000000
# 25%                 2.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count            25976.000000   25976.000000    25976.000000     25976.000000
# mean                 2.756775       2.977094        3.215353         3.261665
# std                  1.412951       1.282133        1.331506         1.355536
# min                  0.000000       1.000000        0.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         4.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#        Seat comfort  Inflight entertainment  On-board service  \
# count  25976.000000            25976.000000      25976.000000
# mean       3.449222                3.357753          3.385664
# std        1.320090                1.338299          1.282088
# min        1.000000                0.000000          0.000000
# 25%        2.000000                2.000000          2.000000
# 50%        4.000000                4.000000          4.000000
# 75%        5.000000                4.000000          4.000000
# max        5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count      25976.000000      25976.000000     25976.000000      25976.000000
# mean           3.350169          3.633238         3.314175          3.649253
# std            1.318862          1.176525         1.269332          1.180681
# min            0.000000          1.000000         1.000000          0.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# count  25976.000000                 25976.00000              25893.000000
# mean       3.286226                    14.30609                 14.740857
# std        1.319330                    37.42316                 37.517539
# min        0.000000                     0.00000                  0.000000
# 25%        2.000000                     0.00000                  0.000000
# 50%        3.000000                     0.00000                  0.000000
# 75%        4.000000                    12.00000                 13.000000
# max        5.000000                  1128.00000               1115.000000

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><h1>4. Data Preparation</h1></div>
# <a class="anchor" id="preparation"></a>

# %% [markdown]
# <strong>Let's assign original dataframes to new ones.</strong>

# %%
train = train_original
test = test_original

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>4.0 Miscellaneous</b>
# </div><a class="anchor" id="miscellaneous"></a>

# %% [markdown]
# <strong>Renaming column labels when they contain blank spaces or any special character, to make them more manageable </strong>

# %%
def rename_column_labels(df, old_str = " ", new_str = "_"):
    #Use case: from "column number 1" to "column_number_1"
    display(Markdown('**Results:**' ))
    cols = df.loc[:,df.columns.str.contains(old_str)].shape[1]
    if cols > 0:
        print("Features changed => {0}".format(cols))
        display(df.loc[:,df.columns.str.contains(old_str)].columns.values)
        df.columns = [label.replace(old_str, new_str ) for label in df.columns]
    else:
        print("No changes were applied")
    return df

# %%
train = rename_column_labels(train," ","_")
train = rename_column_labels(train,"-","_")
train = rename_column_labels(train,":","_")
# Out:
# **Results:**
# Features changed => 19
# array(['Unnamed: 0', 'Customer Type', 'Type of Travel', 'Flight Distance',
#        'Inflight wifi service', 'Departure/Arrival time convenient',
#        'Ease of Online booking', 'Gate location', 'Food and drink',
#        'Online boarding', 'Seat comfort', 'Inflight entertainment',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Inflight service',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype=object)
# **Results:**
# Features changed => 1
# array(['On-board_service'], dtype=object)
# **Results:**
# Features changed => 1
# array(['Unnamed:_0'], dtype=object)

# %%
test = rename_column_labels(test," ","_")
test = rename_column_labels(test,"-","_")
test = rename_column_labels(test,":","_")
# Out:
# **Results:**
# Features changed => 19
# array(['Unnamed: 0', 'Customer Type', 'Type of Travel', 'Flight Distance',
#        'Inflight wifi service', 'Departure/Arrival time convenient',
#        'Ease of Online booking', 'Gate location', 'Food and drink',
#        'Online boarding', 'Seat comfort', 'Inflight entertainment',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Inflight service',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype=object)
# **Results:**
# Features changed => 1
# array(['On-board_service'], dtype=object)
# **Results:**
# Features changed => 1
# array(['Unnamed:_0'], dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>4.1 Remove Columns/Rows</b>
# </div><a class="anchor" id="removing"></a>

# %% [markdown]
# <strong>Let's do a quick review of list of values per each column.</strong>

# %%
def list_column_values(df, number_of_values, print_all):
    display(Markdown('**Results:**' ))
    for col in df.columns[0:]:
        if df[col].nunique() <= number_of_values:
            print(f"{col.ljust(25)}" +  ' ==> ' + str(df[col].sort_values().unique().tolist()) )
        else:  
            if print_all=='True':
               print(f"{col.ljust(25)}" + ' ==> more than ' + str(number_of_values) + ' values')

# %%
list_column_values(train,3,'False')
# Out:
# **Results:**
# Gender                    ==> ['Female', 'Male']
# Customer_Type             ==> ['Loyal Customer', 'disloyal Customer']
# Type_of_Travel            ==> ['Business travel', 'Personal Travel']
# Class                     ==> ['Business', 'Eco', 'Eco Plus']
# satisfaction              ==> ['neutral or dissatisfied', 'satisfied']

# %%
def list_column_values_percentage(df, number_of_values):
    display(Markdown('**Results:**' ))
    print('Columns with less than ' + str(number_of_values) + ' values')
    for col in df.columns[0:]:
        if train[col].nunique() <= number_of_values:
            print(df[col].value_counts()/len(train))

# %%
list_column_values_percentage(train, 3)
# Out:
# **Results:**
# Columns with less than 3 values
# Gender
# Female    0.507459
# Male      0.492541
# Name: count, dtype: float64
# Customer_Type
# Loyal Customer       0.817322
# disloyal Customer    0.182678
# Name: count, dtype: float64
# Type_of_Travel
# Business travel    0.689627
# Personal Travel    0.310373
# Name: count, dtype: float64
# Class
# Business    0.477989
# Eco         0.449886
# Eco Plus    0.072124
# Name: count, dtype: float64
# satisfaction
# neutral or dissatisfied    0.566667
# satisfied                  0.433333
# Name: count, dtype: float64

# %% [markdown]
# <strong>Let's remove unuseful columns such as ID's.</strong>

# %%
train.head()
# Out:
#    Unnamed__0      id  Gender      Customer_Type  Age   Type_of_Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight_Distance  Inflight_wifi_service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival_time_convenient  ...  Inflight_entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On_board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival_Delay_in_Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
def remove_column_values(df, columns_to_remove):
    display(Markdown('**Results:**'))
    print("Original number of features => {}".format(df.shape[1]))
    i=0
    for col in columns_to_remove:
        if col in df.columns:
            i+=1
            df = df.drop(col, axis=1)
            print("Column: {} was removed".format(col))
        else:
            print("Column: {} does not exist".format(col))
    if i==0:
        print('No features were removed')
    else:    
        print("Number of features has been reduced to => {}".format(df.shape[1]))
    return df

# %%
train = remove_column_values(train,['Unnamed__0','id'])
# Out:
# **Results:**
# Original number of features => 25
# Column: Unnamed__0 was removed
# Column: id was removed
# Number of features has been reduced to => 23

# %%
test = remove_column_values(test,['Unnamed__0','id'])
# Out:
# **Results:**
# Original number of features => 25
# Column: Unnamed__0 was removed
# Column: id was removed
# Number of features has been reduced to => 23

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>4.2 Missing Values</b>
# </div> <a class="anchor" id="missing"></a>

# %% [markdown]
# <strong>Let's use firstly a standard function, then a customized one, and finally a visual representation.</strong>

# %%
train.isnull().sum()
# Out:
# Gender                                 0
# Customer_Type                          0
# Age                                    0
# Type_of_Travel                         0
# Class                                  0
# Flight_Distance                        0
# Inflight_wifi_service                  0
# Departure/Arrival_time_convenient      0
# Ease_of_Online_booking                 0
# Gate_location                          0
# Food_and_drink                         0
# Online_boarding                        0
# Seat_comfort                           0
# Inflight_entertainment                 0
# On_board_service                       0
# Leg_room_service                       0
# Baggage_handling                       0
# Checkin_service                        0
# Inflight_service                       0
# Cleanliness                            0
# Departure_Delay_in_Minutes             0
# Arrival_Delay_in_Minutes             310
# satisfaction                           0
# dtype: int64

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)

        display(Markdown('**Results:**'))
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There is/are " + str(mis_val_table_ren_columns.shape[0]) +
              " column(s) that have missing values.")

        return mis_val_table_ren_columns

# %%
missing_values_table(train)
# Out:
# **Results:**
# Your selected dataframe has 23 columns.
# There is/are 1 column(s) that have missing values.
#                           Missing Values  % of Total Values
# Arrival_Delay_in_Minutes             310                0.3

# %%
missing_values_table(test)
# Out:
# **Results:**
# Your selected dataframe has 23 columns.
# There is/are 1 column(s) that have missing values.
#                           Missing Values  % of Total Values
# Arrival_Delay_in_Minutes              83                0.3

# %%
msno.bar(train, color = '#1585E2',fontsize=12,figsize = (8, 5))
# Out:
# <Axes: >

# %% [markdown]
# <strong>Let's remove selected columns/rows with too many missing values if applies.</strong>

# %%
train = remove_column_values(train, ['x'])
# Out:
# **Results:**
# Original number of features => 23
# Column: x does not exist
# No features were removed

# %%
test = remove_column_values(test, ['x'])
# Out:
# **Results:**
# Original number of features => 23
# Column: x does not exist
# No features were removed

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>4.3 Imputation</b>
# </div> <a class="anchor" id="imputation"></a>

# %% [markdown]
# <strong>Let's use mean technique to impute missing values for column(s) identified in previous step.</strong>

# %%
mean_imputer = SimpleImputer(strategy='mean')
train["Arrival_Delay_in_Minutes"] = mean_imputer.fit_transform(train[["Arrival_Delay_in_Minutes"]])

# %% [markdown]
# <strong>Now, let's check the missingness of the dataset.</strong>

# %%
missing_values_table(train)
# Out:
# **Results:**
# Your selected dataframe has 23 columns.
# There is/are 0 column(s) that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
test["Arrival_Delay_in_Minutes"] = mean_imputer.fit_transform(test[["Arrival_Delay_in_Minutes"]])

# %%
missing_values_table(test)
# Out:
# **Results:**
# Your selected dataframe has 23 columns.
# There is/are 0 column(s) that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>4.4 Transforming Columns</b>
# </div> <a class="anchor" id="transforming"></a>

# %% [markdown]
# <strong>Let's review if there are object columns.</strong>

# %%
print("Column data types and their frequency\n{}".format(train.dtypes.value_counts()))
# Out:
# Column data types and their frequency
# int64      17
# object      5
# float64     1
# Name: count, dtype: int64

# %% [markdown]
# <strong>Let's see if some of these columns are numeric.</strong>

# %%
def check_object_columns(df):
    display(Markdown('**Results:**'))
    object_columns_df = df.select_dtypes(include=['object'])
    print(object_columns_df.iloc[0])
    i=0
    for col in object_columns_df:
        if is_numeric_dtype(df[col]):
            i+=1
            print(f"{col.ljust(25)}" + ' ==> is Numeric')
    if i==0:
        print('No numeric columns were found')
    else:    
        print("Number of numeric columns found => {}".format(i))

# %%
check_object_columns(train)
# Out:
# **Results:**
# Gender                               Male
# Customer_Type              Loyal Customer
# Type_of_Travel            Personal Travel
# Class                            Eco Plus
# satisfaction      neutral or dissatisfied
# Name: 0, dtype: object
# No numeric columns were found

# %% [markdown]
# <strong>Let's convert columns tonumeric if any.</strong>

# %%
def columns_to_numeric(df,columns_to_convert = []):
    display(Markdown('**Results:**'))
    i=0
    for col in columns_to_convert:
        if col in df.columns:
            if is_numeric_dtype(df[col]):
                i+=1
                df[col] = df[col].str.rstrip('%').astype('float')
                print("Column {} was converted".format(col))
            else:
                print("Column {} could not be converted".format(col))
        else:
            print("Column {} does not exist".format(col))
    if i==0:
        print('No columns were converted')          
    return df

# %%
train = columns_to_numeric(train,['x','y'])
# Out:
# **Results:**
# Column x does not exist
# Column y does not exist
# No columns were converted

# %% [markdown]
# <strong>Let's convert object columns to strings.</strong>

# %%
def object_to_str(df, to_str_cols):
    display(Markdown('**Results:**'))
    i=0    
    for col in to_str_cols:
        if col in df.columns:
            i+=1
            df[col] = df[col].astype(str)
            print("Column {} was converted".format(col))
        else:
            print("Column {} does not exist".format(col))    
    if i==0:
        print('No columns were converted')          
    return df

# %%
to_str_cols = ['Gender','Customer_Type','Type_of_Travel','Class','satisfaction']
train = object_to_str(train, to_str_cols)
# Out:
# **Results:**
# Column Gender was converted
# Column Customer_Type was converted
# Column Type_of_Travel was converted
# Column Class was converted
# Column satisfaction was converted

# %%
test = object_to_str(test, to_str_cols)
# Out:
# **Results:**
# Column Gender was converted
# Column Customer_Type was converted
# Column Type_of_Travel was converted
# Column Class was converted
# Column satisfaction was converted

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><h1>5. Exploratory Data Analysis</h1></div>
# <a class="anchor" id="exploration"></a>

# %% [markdown]
# <strong>Let's do some data visualization! We'll use seaborn and pandas built-in plotting capabilities.</strong>

# %% [markdown]
# <code style="background:yellow;color:black">Target column is assigned to <strong>l_target</strong> variable to make the visualization code more dynamic.</code>

# %%
l_target = 'satisfaction'

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>5.1 Univariate Analysis</b>
# </div> <a class="anchor" id="univariate"></a>

# %% [markdown]
# <strong>Let's quick review target column values/distribution.</strong>

# %%
list_column_values_percentage(train,15)
# Out:
# **Results:**
# Columns with less than 15 values
# Gender
# Female    0.507459
# Male      0.492541
# Name: count, dtype: float64
# Customer_Type
# Loyal Customer       0.817322
# disloyal Customer    0.182678
# Name: count, dtype: float64
# Type_of_Travel
# Business travel    0.689627
# Personal Travel    0.310373
# Name: count, dtype: float64
# Class
# Business    0.477989
# Eco         0.449886
# Eco Plus    0.072124
# Name: count, dtype: float64
# Inflight_wifi_service
# 3    0.248961
# 2    0.248595
# 4    0.190503
# 1    0.171697
# 5    0.110381
# 0    0.029864
# Name: count, dtype: float64
# Departure/Arrival_time_convenient
# 4    0.245862
# 5    0.215612
# 3    0.172910
# 2    0.165451
# 1    0.149157
# 0    0.051009
# Name: count, dtype: float64
# Ease_of_Online_booking
# 3    0.235304
# 2    0.231185
# 4    0.188357
# 1    0.168665
# 5    0.133306
# 0    0.043184
# Name: count, dtype: float64
# Gate_location
# 3    0.275033
# 4    0.235082
# 2    0.187279
# 1    0.169021
# 5    0.133575
# 0    0.000010
# Name: count, dtype: float64
# Food_and_drink
# 4    0.234438
# 5    0.214746
# 3    0.214621
# 2    0.211618
# 1    0.123547
# 0    0.001030
# Name: count, dtype: float64
# Online_boarding
# 4    0.296062
# 3    0.209848
# 5    0.199347
# 2    0.168473
# 1    0.102903
# 0    0.023368
# Name: count, dtype: float64
# Seat_comfort
# 4    0.305715
# 5    0.254754
# 3    0.179935
# 2    0.143373
# 1    0.116213
# 0    0.000010
# Name: count, dtype: float64
# Inflight_entertainment
# 4    0.283175
# 5    0.242657
# 3    0.184199
# 2    0.169743
# 1    0.120092
# 0    0.000135
# Name: count, dtype: float64
# On_board_service
# 4    0.297072
# 5    0.227595
# 3    0.219751
# 2    0.141294
# 1    0.114259
# 0    0.000029
# Name: count, dtype: float64
# Leg_room_service
# 4    0.277073
# 5    0.237402
# 3    0.193429
# 2    0.187914
# 1    0.099640
# 0    0.004543
# Name: count, dtype: float64
# Baggage_handling
# 4    0.359784
# 5    0.261116
# 3    0.198568
# 2    0.110881
# 1    0.069651
# Name: count, dtype: float64
# Checkin_service
# 4    0.279633
# 3    0.273772
# 5    0.198443
# 2    0.124086
# 1    0.124057
# 0    0.000010
# Name: count, dtype: float64
# Inflight_service
# 4    0.365193
# 5    0.260972
# 3    0.195363
# 2    0.110265
# 1    0.068178
# 0    0.000029
# Name: count, dtype: float64
# Cleanliness
# 4    0.261578
# 3    0.236507
# 5    0.218365
# 2    0.155259
# 1    0.128176
# 0    0.000115
# Name: count, dtype: float64
# satisfaction
# neutral or dissatisfied    0.566667
# satisfied                  0.433333
# Name: count, dtype: float64

# %%
def plot_target_column (df, target):
    ax = sns.countplot(x=target, data=df)
    plt.title('Distribution of ' + target + ' column')
    plt.xlabel('Frequency')
    ax.set_xticklabels(ax.get_xticklabels(),rotation=0)
    total = len(df[target])
    for p in ax.patches:
            percentage = '{:.1f}%'.format(100 * p.get_height()/total)
            x = p.get_x() + p.get_width() + 0.02
            y = p.get_y() + p.get_height()/2
            ax.annotate(percentage, (x, y))
            ax.text(p.get_x()+p.get_width()/2., p.get_height() + 0.2, p.get_height(),ha="center")
    plt.show()

# %%
top_n = 20
value_counts = train['Customer_Type'].value_counts().nlargest(top_n)
sns.countplot(x='Customer_Type', data=train[train['Customer_Type'].isin(value_counts.index)])
# Out:
# <Axes: xlabel='Customer_Type', ylabel='count'>

# %%
plot_target_column(train, l_target)

# %% [markdown]
# <strong>Let's do again a quick review of list of values per each column.</strong>

# %%
list_column_values(train,15,'True')
# Out:
# **Results:**
# Gender                    ==> ['Female', 'Male']
# Customer_Type             ==> ['Loyal Customer', 'disloyal Customer']
# Age                       ==> more than 15 values
# Type_of_Travel            ==> ['Business travel', 'Personal Travel']
# Class                     ==> ['Business', 'Eco', 'Eco Plus']
# Flight_Distance           ==> more than 15 values
# Inflight_wifi_service     ==> [0, 1, 2, 3, 4, 5]
# Departure/Arrival_time_convenient ==> [0, 1, 2, 3, 4, 5]
# Ease_of_Online_booking    ==> [0, 1, 2, 3, 4, 5]
# Gate_location             ==> [0, 1, 2, 3, 4, 5]
# Food_and_drink            ==> [0, 1, 2, 3, 4, 5]
# Online_boarding           ==> [0, 1, 2, 3, 4, 5]
# Seat_comfort              ==> [0, 1, 2, 3, 4, 5]
# Inflight_entertainment    ==> [0, 1, 2, 3, 4, 5]
# On_board_service          ==> [0, 1, 2, 3, 4, 5]
# Leg_room_service          ==> [0, 1, 2, 3, 4, 5]
# Baggage_handling          ==> [1, 2, 3, 4, 5]
# Checkin_service           ==> [0, 1, 2, 3, 4, 5]
# Inflight_service          ==> [0, 1, 2, 3, 4, 5]
# Cleanliness               ==> [0, 1, 2, 3, 4, 5]
# Departure_Delay_in_Minutes ==> more than 15 values
# Arrival_Delay_in_Minutes  ==> more than 15 values
# satisfaction              ==> ['neutral or dissatisfied', 'satisfied']

# %% [markdown]
# <strong>Let's plot categorical columns.</strong>

# %%
def plot_categorical_columns(df):
    categorical = train.select_dtypes(exclude=['int', 'float','int32','float32','int64','float64']).columns
    lcols_in_plot = 2
    lrows_in_plot = math.ceil(len(categorical)/lcols_in_plot)   
    fig, ax = plt.subplots( lrows_in_plot, lcols_in_plot , figsize=(20, 30))
    plt.subplots_adjust(wspace=0.2, hspace=0.4) 
    sns.set(font_scale = 1.1)
    for variable, subplot in zip(categorical, ax.flatten()):
        sns.countplot(train[variable], ax=subplot)
        for label in subplot.get_xticklabels():
            label.set_rotation(45)
            label.set_ha("right")
            label.set_rotation_mode("anchor")

# %%
plot_categorical_columns(train)

# %% [markdown]
# <strong>Let's plot numerical columns.</strong>
# Using standard and customized function.

# %%
hist = train.hist(figsize = (15, 22), layout=(6, 4) , color='#1363a1',alpha=0.8 )

# %%
def plot_numerical_columns(df):
    df = df[df.select_dtypes([np.int64,np.float64]).columns]
    lcols = 2
    lrows = math.ceil(len(df.columns)/lcols)
    plt.figure(figsize=(20,20))
    plt.subplots_adjust(wspace=0.2, hspace=0.5) 
    for i, column in enumerate(df.columns):
        plt.subplot(lrows,lcols,i+1)
        sns.distplot(df[column])

# %%
plot_numerical_columns(train)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>5.2 Bi-variate Analysis</b>
# </div><a class="anchor" id="bivariate"></a>

# %% [markdown]
# <strong>Let's use crosstab function.</strong> For more info <a href="https://www.earthdatascience.org/courses/earth-analytics-bootcamp/git-github-version-control/markdown-jupyter-notebook/" target="_blank">Use this link</a>.

# %%
col = train.Inflight_entertainment
pd.crosstab(train[l_target], [col], margins=True, margins_name="Total", normalize='index')
# Out:
# Inflight_entertainment          0         1         2         3         4  \
# satisfaction
# neutral or dissatisfied  0.000238  0.182289  0.235653  0.237266  0.194008
# satisfied                0.000000  0.038756  0.083554  0.114803  0.399778
# Total                    0.000135  0.120092  0.169743  0.184199  0.283175
#
# Inflight_entertainment          5
# satisfaction
# neutral or dissatisfied  0.150546
# satisfied                0.363109
# Total                    0.242657

# %% [markdown]
# In order to calculate the **correlation matrix** for pairs of categorical features, we need first to encode the textual values into numeric ones to be able to plot

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# Example for whole dataframe
train_encoded = train.copy()
for col in train_encoded.columns:
    if train_encoded[col].dtype == 'object':
        train_encoded[col] = le.fit_transform(train_encoded[col])

# Now you can do:
corr_matrix = train_encoded.corr()
sns.heatmap(corr_matrix, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
plt.subplots(figsize=(15,15))
data = train.corr()
sns.heatmap(data, cmap ='Blues', annot=True, annot_kws={"size": 10})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 2
#       1 plt.subplots(figsize=(15,15))
# ----> 2 data = train.corr()
#       3 sns.heatmap(data, cmap ='Blues', annot=True, annot_kws={"size": 10})
#
# File ~\Downloads\Anacomoda\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\Downloads\Anacomoda\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~\Downloads\Anacomoda\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\Downloads\Anacomoda\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'neutral or dissatisfied'

# %% [markdown]
# A **stacked** column plot can be useful in visualizing the relationship between two categorical variables. We can compare the percentages that each category from one variable contributes to a total across categories of the second variable.

# %%
Inflight_entertainment_vs_Food_and_drink = pd.crosstab(index=train["Inflight_entertainment"], columns=train["Food_and_drink"]) 
Inflight_entertainment_vs_Food_and_drink.plot(kind="bar", figsize=(8,8),stacked=True)
# Out:
# <Axes: xlabel='Inflight_entertainment'>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>5.3 Multivariate Analysis</b>
# </div> <a class="anchor" id="multivariate"></a>

# %% [markdown]
# <strong>Let's compare groups/subgroups in our data. Using colors (hue) to represent different groups</strong>

# %%
sns.boxplot(
    x='Gender', 
    y='Arrival_Delay_in_Minutes', 
    hue='Inflight_entertainment', 
    data=train, 
    # instead of size
)
cond_plot = sns.FacetGrid(
    data=train,
    col='Type_of_Travel',
    hue='Gender',
    col_wrap=3,
    height=6,   # instead of size
    aspect=1
)
cond_plot.map(sns.scatterplot, 'Inflight_entertainment', 'Arrival_Delay_in_Minutes').add_legend()

# %%
cond_plot = sns.FacetGrid(data=train, col='Type_of_Travel', hue='Gender', col_wrap=3 , height=6,aspect=1)
cond_plot.map(sns.scatterplot, 'Inflight_entertainment', 'Arrival_Delay_in_Minutes').add_legend()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><h1>6. Feature Engineering</h1></div>
# <a class="anchor" id="engineering"></a>

# %% [markdown]
# <strong>Let's move tables to new ones.</strong>

# %%
train_fe = train
test_fe = test

# %%
print("Column data types and their frequency\n{}".format(train_fe.dtypes.value_counts()))
# Out:
# Column data types and their frequency
# int64      17
# object      5
# float64     1
# Name: count, dtype: int64

# %%
list_column_values(train_fe,15,'True')
# Out:
# **Results:**
# Gender                    ==> ['Female', 'Male']
# Customer_Type             ==> ['Loyal Customer', 'disloyal Customer']
# Age                       ==> more than 15 values
# Type_of_Travel            ==> ['Business travel', 'Personal Travel']
# Class                     ==> ['Business', 'Eco', 'Eco Plus']
# Flight_Distance           ==> more than 15 values
# Inflight_wifi_service     ==> [0, 1, 2, 3, 4, 5]
# Departure/Arrival_time_convenient ==> [0, 1, 2, 3, 4, 5]
# Ease_of_Online_booking    ==> [0, 1, 2, 3, 4, 5]
# Gate_location             ==> [0, 1, 2, 3, 4, 5]
# Food_and_drink            ==> [0, 1, 2, 3, 4, 5]
# Online_boarding           ==> [0, 1, 2, 3, 4, 5]
# Seat_comfort              ==> [0, 1, 2, 3, 4, 5]
# Inflight_entertainment    ==> [0, 1, 2, 3, 4, 5]
# On_board_service          ==> [0, 1, 2, 3, 4, 5]
# Leg_room_service          ==> [0, 1, 2, 3, 4, 5]
# Baggage_handling          ==> [1, 2, 3, 4, 5]
# Checkin_service           ==> [0, 1, 2, 3, 4, 5]
# Inflight_service          ==> [0, 1, 2, 3, 4, 5]
# Cleanliness               ==> [0, 1, 2, 3, 4, 5]
# Departure_Delay_in_Minutes ==> more than 15 values
# Arrival_Delay_in_Minutes  ==> more than 15 values
# satisfaction              ==> ['neutral or dissatisfied', 'satisfied']

# %% [markdown]
# <strong>Let's review specific columns distribution.</strong>

# %%
sns.countplot(x='Type_of_Travel',data=train_fe, palette='hls')
plt.show();

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>6.1 General Transformation</b>
# </div> <a class="anchor" id="general_trans"></a>

# %% [markdown]
# <strong>Let's replace categorical values with numerical values.</strong>

# %%
train_fe['satisfaction'].replace(['neutral or dissatisfied','satisfied'],[0,1],inplace=True)

# %%
test_fe['satisfaction'].replace(['neutral or dissatisfied','satisfied'],[0,1],inplace=True)

# %%
print("Column data types and their frequency\n{}".format(train_fe.dtypes.value_counts()))
# Out:
# Column data types and their frequency
# int64      18
# object      4
# float64     1
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>6.2 Encoding</b>
# </div> <a class="anchor" id="encoding"></a>

# %%
train_fe.head()
# Out:
#    Gender      Customer_Type  Age   Type_of_Travel     Class  Flight_Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease_of_Online_booking  Gate_location  ...  Inflight_entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On_board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival_Delay_in_Minutes  satisfaction
# 0                      18.0             0
# 1                       6.0             0
# 2                       0.0             1
# 3                       9.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]

# %% [markdown]
# Basically the <strong>fit </strong>method, prepare the encoder (fit on your data i.e. prepare the mapping) but don't transform the data.
# You have to call <strong>transform</strong> to transform the data , or use <strong>fit_transform</strong> which fit and transform the same data.

# %%
print("Column data types and their frequency\n{}".format(train_fe.dtypes.value_counts()))
# Out:
# Column data types and their frequency
# int64      18
# object      4
# float64     1
# Name: count, dtype: int64

# %% [markdown]
# ### LABEL ENCODER

# %%
def labelencoder(df, encode_cols ):
    '''
    Label Encoder function
    '''
    print('Processing label encoder features..\nOld df shape:{}'.format(df.shape))
    enc = LabelEncoder()
    for col in encode_cols:
        enc.fit(df[col])
        df[col] = enc.transform(df[col])
    display(Markdown('**Results:**'))
    print('New df shape:{}'.format(df.shape))
    return df

# %% [markdown]
# <strong>This dataset does not have any candidate to use label encoder </strong>

# %%
encode_cols = []
train_fe = labelencoder(train_fe,encode_cols)
# Out:
# Processing label encoder features..
# Old df shape:(103904, 23)
# **Results:**
# New df shape:(103904, 23)

# %%
test_fe = labelencoder(test_fe,encode_cols)
# Out:
# Processing label encoder features..
# Old df shape:(25976, 23)
# **Results:**
# New df shape:(25976, 23)

# %%
train_fe.head()
# Out:
#    Gender      Customer_Type  Age   Type_of_Travel     Class  Flight_Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease_of_Online_booking  Gate_location  ...  Inflight_entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On_board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival_Delay_in_Minutes  satisfaction
# 0                      18.0             0
# 1                       6.0             0
# 2                       0.0             1
# 3                       9.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]

# %%
train_fe['Class'].unique().tolist()
# Out:
# ['Eco Plus', 'Business', 'Eco']

# %%
def ordinalencoder(df_col, categories ):
    '''
    Ordinal Encoder function
    '''
    # Using pandas factorize method for ordinal data
    l_categories = pd.Categorical(df_col, categories=['Business','Eco Plus','Eco'], ordered=True)
    l_col = df_col.name
    # Factorizing the column data
    labels, unique = pd.factorize(l_categories, sort=True)
    df_col = labels
    display(Markdown('**Results:**'))
    print('Conversion applied to column: {}'.format(l_col))
    return df_col

# %%
train_fe['Class'].unique().tolist()
# Out:
# ['Eco Plus', 'Business', 'Eco']

# %%
categories=['Business','Eco Plus','Eco']

train_fe['Class'] = ordinalencoder(train_fe['Class'], categories)
# Out:
# **Results:**
# Conversion applied to column: Class

# %%
train_fe['Class'].unique().tolist()
# Out:
# [1, 0, 2]

# %% [markdown]
# <strong>Now, let's apply it to test </strong>

# %%
test_fe['Class'].unique().tolist()
# Out:
# ['Eco', 'Business', 'Eco Plus']

# %%
test_fe['Class'] = ordinalencoder(test_fe['Class'], categories)
# Out:
# **Results:**
# Conversion applied to column: Class

# %%
test_fe['Class'].unique().tolist()
# Out:
# [2, 0, 1]

# %%
train_fe.head()
# Out:
#    Gender      Customer_Type  Age   Type_of_Travel  Class  Flight_Distance  \
# 0    Male     Loyal Customer   13  Personal Travel      1              460
# 1    Male  disloyal Customer   25  Business travel      0              235
# 2  Female     Loyal Customer   26  Business travel      0             1142
# 3  Female     Loyal Customer   25  Business travel      0              562
# 4    Male     Loyal Customer   61  Business travel      0              214
#
#    Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease_of_Online_booking  Gate_location  ...  Inflight_entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On_board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival_Delay_in_Minutes  satisfaction
# 0                      18.0             0
# 1                       6.0             0
# 2                       0.0             1
# 3                       9.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]

# %%
def one_hot_encoder(df, cat_cols ):
    '''
    One-Hot Encoder function
    '''
    print('Creating OHE features..\nOld df shape:{}'.format(df.shape))
    df = pd.get_dummies(df, columns=cat_cols)
    print('New df shape:{}'.format(df.shape))
    return df

# %%
cat_cols = ['Gender','Customer_Type','Type_of_Travel']
train_fe = one_hot_encoder(train_fe,cat_cols)
test_fe = one_hot_encoder(test_fe,cat_cols)
# Out:
# Creating OHE features..
# Old df shape:(103904, 23)
# New df shape:(103904, 26)
# Creating OHE features..
# Old df shape:(25976, 23)
# New df shape:(25976, 26)

# %%
train_fe.head()
# Out:
#    Age  Class  Flight_Distance  Inflight_wifi_service  \
# 0   13      1              460                      3
# 1   25      0              235                      3
# 2   26      0             1142                      2
# 3   25      0              562                      2
# 4   61      0              214                      3
#
#    Departure/Arrival_time_convenient  Ease_of_Online_booking  Gate_location  \
# 0                                  4                       3              1
# 1                                  2                       3              3
# 2                                  2                       2              2
# 3                                  5                       5              5
# 4                                  3                       3              3
#
#    Food_and_drink  Online_boarding  Seat_comfort  ...  Cleanliness  \
# 0               5                3             5  ...            5
# 1               1                3             1  ...            1
# 2               5                5             5  ...            5
# 3               2                2             2  ...            2
# 4               4                5             5  ...            3
#
#    Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  satisfaction  \
# 0                          25                      18.0             0
# 1                           1                       6.0             0
# 2                           0                       0.0             1
# 3                          11                       9.0             0
# 4                           0                       0.0             1
#
#    Gender_Female  Gender_Male  Customer_Type_Loyal Customer  \
# 0          False         True                          True
# 1          False         True                         False
# 2           True        False                          True
# 3           True        False                          True
# 4          False         True                          True
#
#    Customer_Type_disloyal Customer  Type_of_Travel_Business travel  \
# 0                            False                           False
# 1                             True                            True
# 2                            False                            True
# 3                            False                            True
# 4                            False                            True
#
#    Type_of_Travel_Personal Travel
# 0                            True
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
# [5 rows x 26 columns]

# %%
test_fe.head()
# Out:
#    Age  Class  Flight_Distance  Inflight_wifi_service  \
# 0   52      2              160                      5
# 1   36      0             2863                      1
# 2   20      2              192                      2
# 3   44      0             3377                      0
# 4   49      2             1182                      2
#
#    Departure/Arrival_time_convenient  Ease_of_Online_booking  Gate_location  \
# 0                                  4                       3              4
# 1                                  1                       3              1
# 2                                  0                       2              4
# 3                                  0                       0              2
# 4                                  3                       4              3
#
#    Food_and_drink  Online_boarding  Seat_comfort  ...  Cleanliness  \
# 0               3                4             3  ...            5
# 1               5                4             5  ...            5
# 2               2                2             2  ...            2
# 3               3                4             4  ...            4
# 4               4                1             2  ...            4
#
#    Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  satisfaction  \
# 0                          50                      44.0             1
# 1                           0                       0.0             1
# 2                           0                       0.0             0
# 3                           0                       6.0             1
# 4                           0                      20.0             1
#
#    Gender_Female  Gender_Male  Customer_Type_Loyal Customer  \
# 0           True        False                          True
# 1           True        False                          True
# 2          False         True                         False
# 3          False         True                          True
# 4           True        False                          True
#
#    Customer_Type_disloyal Customer  Type_of_Travel_Business travel  \
# 0                            False                            True
# 1                            False                            True
# 2                             True                            True
# 3                            False                            True
# 4                            False                            True
#
#    Type_of_Travel_Personal Travel
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
# [5 rows x 26 columns]

# %%
plt.subplots(figsize=(20,20))
data = train_fe.corr()
sns.heatmap(data, cmap ='Blues', annot=True, annot_kws={"size": 12})
# Out:
# <Axes: >

# %% [markdown]
# <strong>Let's new columns identified as unuseful.</strong>

# %%
rm_col=[]

# %%
train_fe = remove_column_values(train_fe, rm_col)
# Out:
# **Results:**
# Original number of features => 26
# No features were removed

# %%
test_fe = remove_column_values(test_fe, rm_col)
# Out:
# **Results:**
# Original number of features => 26
# No features were removed

# %%
train_fe.head()
# Out:
#    Age  Class  Flight_Distance  Inflight_wifi_service  \
# 0   13      1              460                      3
# 1   25      0              235                      3
# 2   26      0             1142                      2
# 3   25      0              562                      2
# 4   61      0              214                      3
#
#    Departure/Arrival_time_convenient  Ease_of_Online_booking  Gate_location  \
# 0                                  4                       3              1
# 1                                  2                       3              3
# 2                                  2                       2              2
# 3                                  5                       5              5
# 4                                  3                       3              3
#
#    Food_and_drink  Online_boarding  Seat_comfort  ...  Cleanliness  \
# 0               5                3             5  ...            5
# 1               1                3             1  ...            1
# 2               5                5             5  ...            5
# 3               2                2             2  ...            2
# 4               4                5             5  ...            3
#
#    Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  satisfaction  \
# 0                          25                      18.0             0
# 1                           1                       6.0             0
# 2                           0                       0.0             1
# 3                          11                       9.0             0
# 4                           0                       0.0             1
#
#    Gender_Female  Gender_Male  Customer_Type_Loyal Customer  \
# 0          False         True                          True
# 1          False         True                         False
# 2           True        False                          True
# 3           True        False                          True
# 4          False         True                          True
#
#    Customer_Type_disloyal Customer  Type_of_Travel_Business travel  \
# 0                            False                           False
# 1                             True                            True
# 2                            False                            True
# 3                            False                            True
# 4                            False                            True
#
#    Type_of_Travel_Personal Travel
# 0                            True
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
# [5 rows x 26 columns]

# %%
test_fe.head()
# Out:
#    Age  Class  Flight_Distance  Inflight_wifi_service  \
# 0   52      2              160                      5
# 1   36      0             2863                      1
# 2   20      2              192                      2
# 3   44      0             3377                      0
# 4   49      2             1182                      2
#
#    Departure/Arrival_time_convenient  Ease_of_Online_booking  Gate_location  \
# 0                                  4                       3              4
# 1                                  1                       3              1
# 2                                  0                       2              4
# 3                                  0                       0              2
# 4                                  3                       4              3
#
#    Food_and_drink  Online_boarding  Seat_comfort  ...  Cleanliness  \
# 0               3                4             3  ...            5
# 1               5                4             5  ...            5
# 2               2                2             2  ...            2
# 3               3                4             4  ...            4
# 4               4                1             2  ...            4
#
#    Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  satisfaction  \
# 0                          50                      44.0             1
# 1                           0                       0.0             1
# 2                           0                       0.0             0
# 3                           0                       6.0             1
# 4                           0                      20.0             1
#
#    Gender_Female  Gender_Male  Customer_Type_Loyal Customer  \
# 0           True        False                          True
# 1           True        False                          True
# 2          False         True                         False
# 3          False         True                          True
# 4           True        False                          True
#
#    Customer_Type_disloyal Customer  Type_of_Travel_Business travel  \
# 0                            False                            True
# 1                            False                            True
# 2                             True                            True
# 3                            False                            True
# 4                            False                            True
#
#    Type_of_Travel_Personal Travel
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
# [5 rows x 26 columns]

# %%
cols = train_fe.columns.tolist()
colIdx = train_fe.columns.get_loc(l_target)
cols = cols[colIdx:colIdx+1] + cols[0:colIdx] + cols[colIdx+1:]
train_aws = train_fe[cols]

# %%
train_aws.head()
# Out:
#    satisfaction  Age  Class  Flight_Distance  Inflight_wifi_service  \
# 0             0   13      1              460                      3
# 1             0   25      0              235                      3
# 2             1   26      0             1142                      2
# 3             0   25      0              562                      2
# 4             1   61      0              214                      3
#
#    Departure/Arrival_time_convenient  Ease_of_Online_booking  Gate_location  \
# 0                                  4                       3              1
# 1                                  2                       3              3
# 2                                  2                       2              2
# 3                                  5                       5              5
# 4                                  3                       3              3
#
#    Food_and_drink  Online_boarding  ...  Inflight_service  Cleanliness  \
# 0               5                3  ...                 5            5
# 1               1                3  ...                 4            1
# 2               5                5  ...                 4            5
# 3               2                2  ...                 4            2
# 4               4                5  ...                 3            3
#
#    Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  Gender_Female  \
# 0                          25                      18.0          False
# 1                           1                       6.0          False
# 2                           0                       0.0           True
# 3                          11                       9.0           True
# 4                           0                       0.0          False
#
#    Gender_Male  Customer_Type_Loyal Customer  Customer_Type_disloyal Customer  \
# 0         True                          True                            False
# 1         True                         False                             True
# 2        False                          True                            False
# 3        False                          True                            False
# 4         True                          True                            False
#
#    Type_of_Travel_Business travel  Type_of_Travel_Personal Travel
# 0                           False                            True
# 1                            True                           False
# 2                            True                           False
# 3                            True                           False
# 4                            True                           False
#
# [5 rows x 26 columns]

# %%
cols = test_fe.columns.tolist()
colIdx = test_fe.columns.get_loc(l_target)
cols = cols[colIdx:colIdx+1] + cols[0:colIdx] + cols[colIdx+1:]
test_aws = test_fe[cols]

# %%
test_aws.head()
# Out:
#    satisfaction  Age  Class  Flight_Distance  Inflight_wifi_service  \
# 0             1   52      2              160                      5
# 1             1   36      0             2863                      1
# 2             0   20      2              192                      2
# 3             1   44      0             3377                      0
# 4             1   49      2             1182                      2
#
#    Departure/Arrival_time_convenient  Ease_of_Online_booking  Gate_location  \
# 0                                  4                       3              4
# 1                                  1                       3              1
# 2                                  0                       2              4
# 3                                  0                       0              2
# 4                                  3                       4              3
#
#    Food_and_drink  Online_boarding  ...  Inflight_service  Cleanliness  \
# 0               3                4  ...                 5            5
# 1               5                4  ...                 4            5
# 2               2                2  ...                 2            2
# 3               3                4  ...                 1            4
# 4               4                1  ...                 2            4
#
#    Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes  Gender_Female  \
# 0                          50                      44.0           True
# 1                           0                       0.0           True
# 2                           0                       0.0          False
# 3                           0                       6.0          False
# 4                           0                      20.0           True
#
#    Gender_Male  Customer_Type_Loyal Customer  Customer_Type_disloyal Customer  \
# 0        False                          True                            False
# 1        False                          True                            False
# 2         True                         False                             True
# 3         True                          True                            False
# 4        False                          True                            False
#
#    Type_of_Travel_Business travel  Type_of_Travel_Personal Travel
# 0                            True                           False
# 1                            True                           False
# 2                            True                           False
# 3                            True                           False
# 4                            True                           False
#
# [5 rows x 26 columns]

# %% [markdown]
# <strong> Let's remove headers and save datasets as files </strong>

# %%
train_aws.to_csv('train_aws.csv',  header = False, index = False)
test_aws.to_csv('test_aws.csv',  header = False, index = False)

# %%
X = train_fe.drop([l_target], axis=1)
y = train_fe[l_target].reset_index(drop=True)

X_test = test_fe.drop([l_target], axis=1)

X.shape, y.shape, X_test.shape
# Out:
# ((103904, 25), (103904,), (25976, 25))

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %%
x_val.head()
# Out:
#        Age  Class  Flight_Distance  Inflight_wifi_service  \
# 79897   22      2              157                      4
# 76972   22      0              334                      5
# 87038   38      2              920                      2
# 90082   54      0             3086                      3
# 99531   38      0              808                      2
#
#        Departure/Arrival_time_convenient  Ease_of_Online_booking  \
# 79897                                  2                       4
# 76972                                  0                       5
# 87038                                  2                       2
# 90082                                  5                       3
# 99531                                  2                       2
#
#        Gate_location  Food_and_drink  Online_boarding  Seat_comfort  ...  \
# 79897              3               4                4             4  ...
# 76972              3               3                5             3  ...
# 87038              4               3                2             2  ...
# 90082              3               5                3             5  ...
# 99531              2               5                3             1  ...
#
#        Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 79897                 4            4                          20
# 76972                 5            3                         105
# 87038                 3            3                           0
# 90082                 3            1                           0
# 99531                 4            1                          17
#
#        Arrival_Delay_in_Minutes  Gender_Female  Gender_Male  \
# 79897                       0.0           True        False
# 76972                     127.0          False         True
# 87038                       2.0           True        False
# 90082                       0.0          False         True
# 99531                       0.0          False         True
#
#        Customer_Type_Loyal Customer  Customer_Type_disloyal Customer  \
# 79897                         False                             True
# 76972                         False                             True
# 87038                         False                             True
# 90082                          True                            False
# 99531                          True                            False
#
#        Type_of_Travel_Business travel  Type_of_Travel_Personal Travel
# 79897                            True                           False
# 76972                            True                           False
# 87038                            True                           False
# 90082                            True                           False
# 99531                            True                           False
#
# [5 rows x 25 columns]
